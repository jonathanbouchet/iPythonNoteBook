# %% [markdown]
# # Polynomial Regression

# %%
# For data
import pandas as pd
from pandas import Series,DataFrame
import numpy as np
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
np.random.seed(2)
X = np.random.normal(3.0, 1.0, 1000)
Y = np.random.normal(50.0, 10.0, 1000) / X

scatter(X, Y)

# %%
x = Series(X)
y = Series(Y)
d = {'x':x,'y':y}
data = pd.DataFrame(d)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#           x          y
# 0  2.583242  20.121032
# 1  2.943733  18.129483
# 2  0.863804  50.964608
# 3  4.640271  11.503502
# 4  1.206564  35.389506

# %%
sns.lmplot(x="x", y="y", data=data,order=-2, ci=None);

# %%
p4 = np.poly1d(np.polyfit(x, y, 4))
xp = np.linspace(0, 7, 100)
plt.scatter(x, y)
plt.plot(xp, p4(xp), c='r')
plt.show()

# %%
def func(x, a, b):
    return a * (1./x) + b

# %%
from scipy.optimize import curve_fit

# %%
popt, pcov = curve_fit(func, x, y)

# %%
popt
# Out:
# array([ 52.01762344,  -0.80644252])

# %%
xx = np.linspace(0.1,7, 100)
res = func(xx, *popt)

# %%
plt.scatter(x,y)
plt.plot(xx, res,'r',label='Best Fit Line')
